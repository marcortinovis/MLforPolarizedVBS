# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
lep_data_tt = np.load('../processed_ntuples/vanilla/TT/scalednorm/lep_data_tt.npy')
vbsjet_data_tt = np.load('../processed_ntuples/vanilla/TT/scalednorm/vbsjet_data_tt.npy')
nvbsjet_data_tt = np.load('../processed_ntuples/vanilla/TT/scalednorm/nvbsjet_data_tt.npy')
jj_data_tt = np.load('../processed_ntuples/vanilla/TT/scalednorm/jj_data_tt.npy')
met_data_tt = np.load('../processed_ntuples/vanilla/TT/scalednorm/met_data_tt.npy')
nu_data_tt = np.load('../processed_ntuples/vanilla/TT/scalednorm/nu_data_tt.npy')

lep_data_tl = np.load('../processed_ntuples/vanilla/TL/scalednorm/lep_data_tl.npy')
vbsjet_data_tl = np.load('../processed_ntuples/vanilla/TL/scalednorm/vbsjet_data_tl.npy')
nvbsjet_data_tl = np.load('../processed_ntuples/vanilla/TL/scalednorm/nvbsjet_data_tl.npy')
jj_data_tl = np.load('../processed_ntuples/vanilla/TL/scalednorm/jj_data_tl.npy')
met_data_tl = np.load('../processed_ntuples/vanilla/TL/scalednorm/met_data_tl.npy')
nu_data_tl = np.load('../processed_ntuples/vanilla/TL/scalednorm/nu_data_tl.npy')

lep_data_ll = np.load('../processed_ntuples/vanilla/LL/scalednorm/lep_data_ll.npy')
vbsjet_data_ll = np.load('../processed_ntuples/vanilla/LL/scalednorm/vbsjet_data_ll.npy')
nvbsjet_data_ll = np.load('../processed_ntuples/vanilla/LL/scalednorm/nvbsjet_data_ll.npy')
jj_data_ll = np.load('../processed_ntuples/vanilla/LL/scalednorm/jj_data_ll.npy')
met_data_ll = np.load('../processed_ntuples/vanilla/LL/scalednorm/met_data_ll.npy')
nu_data_ll = np.load('../processed_ntuples/vanilla/LL/scalednorm/nu_data_ll.npy')

# %%
lep_dic_tt = {'lepPt1': lep_data_tt.T[0,0], 'lepPt2': lep_data_tt.T[0,1], 'lepEta1': lep_data_tt.T[1,0], 'lepEta2': lep_data_tt.T[1,1], 'lepPhi1': lep_data_tt.T[2,0], 'lepPhi2': lep_data_tt.T[2,1]}
vbsjet_dic_tt = {'vbsjetPt1': vbsjet_data_tt.T[0,0], 'vbsjetPt2': vbsjet_data_tt.T[0,1], 'vbsjetEta1': vbsjet_data_tt.T[1,0], 'vbsjetEta2': vbsjet_data_tt.T[1,1], 'vbsjetPhi1': vbsjet_data_tt.T[2,0], 'vbsjetPhi2': vbsjet_data_tt.T[2,1], 'vbsjetM1': vbsjet_data_tt.T[3,0], 'vbsjetM2': vbsjet_data_tt.T[3,1]}
nvbsjet_dic_tt = {'nvbsjetPt1': nvbsjet_data_tt.T[0,0], 'nvbsjetPt2': nvbsjet_data_tt.T[0,1], 'nvbsjetEta1': nvbsjet_data_tt.T[1,0], 'nvbsjetEta2': nvbsjet_data_tt.T[1,1], 'nvbsjetPhi1': nvbsjet_data_tt.T[2,0], 'nvbsjetPhi2': nvbsjet_data_tt.T[2,1], 'nvbsjetM1': nvbsjet_data_tt.T[3,0], 'nvbsjetM2': nvbsjet_data_tt.T[3,1]}
jj_dic_tt = {'mjj': jj_data_tt.T[0,0], 'detajj': jj_data_tt.T[1,0]}
met_dic_tt = {'ptMET': met_data_tt.T[0,0], 'phiMET': met_data_tt.T[1,0]}
nu_dic_tt = {'ptv1': nu_data_tt.T[0,0], 'ptv2': nu_data_tt.T[0,1], 'etav1': nu_data_tt.T[1,0], 'etav2': nu_data_tt.T[1,1], 'phiv1': nu_data_tt.T[2,0], 'phiv2': nu_data_tt.T[2,1]}
dic_tt = lep_dic_tt | vbsjet_dic_tt | nvbsjet_dic_tt | jj_dic_tt | met_dic_tt | nu_dic_tt
df_tt = pd.DataFrame(dic_tt)

lep_dic_tl = {'lepPt1': lep_data_tl.T[0,0], 'lepPt2': lep_data_tl.T[0,1], 'lepEta1': lep_data_tl.T[1,0], 'lepEta2': lep_data_tl.T[1,1], 'lepPhi1': lep_data_tl.T[2,0], 'lepPhi2': lep_data_tl.T[2,1]}
vbsjet_dic_tl = {'vbsjetPt1': vbsjet_data_tl.T[0,0], 'vbsjetPt2': vbsjet_data_tl.T[0,1], 'vbsjetEta1': vbsjet_data_tl.T[1,0], 'vbsjetEta2': vbsjet_data_tl.T[1,1], 'vbsjetPhi1': vbsjet_data_tl.T[2,0], 'vbsjetPhi2': vbsjet_data_tl.T[2,1], 'vbsjetM1': vbsjet_data_tl.T[3,0], 'vbsjetM2': vbsjet_data_tl.T[3,1]}
nvbsjet_dic_tl = {'nvbsjetPt1': nvbsjet_data_tl.T[0,0], 'nvbsjetPt2': nvbsjet_data_tl.T[0,1], 'nvbsjetEta1': nvbsjet_data_tl.T[1,0], 'nvbsjetEta2': nvbsjet_data_tl.T[1,1], 'nvbsjetPhi1': nvbsjet_data_tl.T[2,0], 'nvbsjetPhi2': nvbsjet_data_tl.T[2,1], 'nvbsjetM1': nvbsjet_data_tl.T[3,0], 'nvbsjetM2': nvbsjet_data_tl.T[3,1]}
jj_dic_tl = {'mjj': jj_data_tl.T[0,0], 'detajj': jj_data_tl.T[1,0]}
met_dic_tl = {'ptMET': met_data_tl.T[0,0], 'phiMET': met_data_tl.T[1,0]}
nu_dic_tl = {'ptv1': nu_data_tl.T[0,0], 'ptv2': nu_data_tl.T[0,1], 'etav1': nu_data_tl.T[1,0], 'etav2': nu_data_tl.T[1,1], 'phiv1': nu_data_tl.T[2,0], 'phiv2': nu_data_tl.T[2,1]}
dic_tl = lep_dic_tl | vbsjet_dic_tl | nvbsjet_dic_tl | jj_dic_tl | met_dic_tl | nu_dic_tl
df_tl = pd.DataFrame(dic_tl)

lep_dic_ll = {'lepPt1': lep_data_ll.T[0,0], 'lepPt2': lep_data_ll.T[0,1], 'lepEta1': lep_data_ll.T[1,0], 'lepEta2': lep_data_ll.T[1,1], 'lepPhi1': lep_data_ll.T[2,0], 'lepPhi2': lep_data_ll.T[2,1]}
vbsjet_dic_ll = {'vbsjetPt1': vbsjet_data_ll.T[0,0], 'vbsjetPt2': vbsjet_data_ll.T[0,1], 'vbsjetEta1': vbsjet_data_ll.T[1,0], 'vbsjetEta2': vbsjet_data_ll.T[1,1], 'vbsjetPhi1': vbsjet_data_ll.T[2,0], 'vbsjetPhi2': vbsjet_data_ll.T[2,1], 'vbsjetM1': vbsjet_data_ll.T[3,0], 'vbsjetM2': vbsjet_data_ll.T[3,1]}
nvbsjet_dic_ll = {'nvbsjetPt1': nvbsjet_data_ll.T[0,0], 'nvbsjetPt2': nvbsjet_data_ll.T[0,1], 'nvbsjetEta1': nvbsjet_data_ll.T[1,0], 'nvbsjetEta2': nvbsjet_data_ll.T[1,1], 'nvbsjetPhi1': nvbsjet_data_ll.T[2,0], 'nvbsjetPhi2': nvbsjet_data_ll.T[2,1], 'nvbsjetM1': nvbsjet_data_ll.T[3,0], 'nvbsjetM2': nvbsjet_data_ll.T[3,1]}
jj_dic_ll = {'mjj': jj_data_ll.T[0,0], 'detajj': jj_data_ll.T[1,0]}
met_dic_ll = {'ptMET': met_data_ll.T[0,0], 'phiMET': met_data_ll.T[1,0]}
nu_dic_ll = {'ptv1': nu_data_ll.T[0,0], 'ptv2': nu_data_ll.T[0,1], 'etav1': nu_data_ll.T[1,0], 'etav2': nu_data_ll.T[1,1], 'phiv1': nu_data_ll.T[2,0], 'phiv2': nu_data_ll.T[2,1]}
dic_ll = lep_dic_ll | vbsjet_dic_ll | nvbsjet_dic_ll | jj_dic_ll | met_dic_ll | nu_dic_ll
df_ll = pd.DataFrame(dic_ll)

# %%
features = list(df_tt.columns)
print(features)
f_dict = dict(zip(range(len(features)), features))
#log_features = ['vbsjetPt1', 'vbsjetPt2', 'vbsjetM1', 'vbsjetM2', 'lepPt1', 'lepPt2', 'nvbsjetPt1', 'nvbsjetP2', 'nvbsjetM1', 'nvbsjetM2', 'mjj', 'ptMET', 'ptv1', 'ptv2']
#log_mask = np.isin(features, log_features)
# Out:
# ['lepPt1', 'lepPt2', 'lepEta1', 'lepEta2', 'lepPhi1', 'lepPhi2', 'vbsjetPt1', 'vbsjetPt2', 'vbsjetEta1', 'vbsjetEta2', 'vbsjetPhi1', 'vbsjetPhi2', 'vbsjetM1', 'vbsjetM2', 'nvbsjetPt1', 'nvbsjetPt2', 'nvbsjetEta1', 'nvbsjetEta2', 'nvbsjetPhi1', 'nvbsjetPhi2', 'nvbsjetM1', 'nvbsjetM2', 'mjj', 'detajj', 'ptMET', 'phiMET', 'ptv1', 'ptv2', 'etav1', 'etav2', 'phiv1', 'phiv2']

# %%
binss_tt = []
binss_tl = []
binss_ll = []

edgess_tt = []
edgess_tl = []
edgess_ll = []

# %%
fig, ax = plt.subplots(ncols=8, nrows=4, figsize=(20,10))

for i in range(4):
    for j in range(8):
        if (i*8+j > 13 and i*8+j < 22):
            bins_tt, edges_tt, hist_tt = ax[i,j].hist([x for x in df_tt[features[i*8+j]].to_numpy() if x != 0.], bins=50, density=True, histtype='step')
            bins_tl, edges_tl, hist_tl = ax[i,j].hist([x for x in df_tl[features[i*8+j]].to_numpy() if x != 0.], bins=50, density=True, histtype='step')
            bins_ll, edges_ll, hist_ll = ax[i,j].hist([x for x in df_ll[features[i*8+j]].to_numpy() if x != 0.], bins=50, density=True, histtype='step')
        else:
            bins_tt, edges_tt, hist_tt = ax[i,j].hist(df_tt[features[i*8+j]].to_numpy(), bins=50, density=True, histtype='step')
            bins_tl, edges_tl, hist_tl = ax[i,j].hist(df_tl[features[i*8+j]].to_numpy(), bins=50, density=True, histtype='step')
            bins_ll, edges_ll, hist_ll = ax[i,j].hist(df_ll[features[i*8+j]].to_numpy(), bins=50, density=True, histtype='step')
        ax[i,j].set_title(features[i*8+j])
        #if log_mask[i*8+j]: ax[i,j].set_xscale('log')
        binss_tt.append(bins_tt)
        binss_tl.append(bins_tl)
        binss_ll.append(bins_ll)
        edgess_tt.append([0.5*(e1+e2) for e1, e2 in zip(edges_tt[:-1], edges_tt[1:])])
        edgess_tl.append([0.5*(e1+e2) for e1, e2 in zip(edges_tl[:-1], edges_tl[1:])])
        edgess_ll.append([0.5*(e1+e2) for e1, e2 in zip(edges_ll[:-1], edges_ll[1:])])

fig.suptitle('Features extracted from ROOT data (SSWW_polarized_CMrf.root): three classes TT, TL, LL, normalized histograms')
fig.legend([hist_tt[0], hist_tl[0], hist_ll[0]], ['TT', 'TL', 'LL'], loc="upper right", bbox_to_anchor=(0.9,1.))
plt.legend()
plt.tight_layout()
plt.savefig('scaled_features.png')
# Out:
# C:\Users\marco\AppData\Local\Temp\ipykernel_9380\2704356543.py:24: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
pulls_tl = []
pulls_tt = []
pulls_tx = []
for bins_ll in binss_ll:
    pulls_tl.append([(a-b)/b for a, b in zip(bins_ll, bins_tl)])
    pulls_tt.append([(a-b)/b for a, b in zip(bins_ll, bins_tt)])
    pulls_tx.append([(a-b)/b for a, b in zip(bins_ll, bins_tt+bins_tl)])
# Out:
# C:\Users\marco\AppData\Local\Temp\ipykernel_9380\2407593847.py:5: RuntimeWarning: divide by zero encountered in scalar divide
#   pulls_tl.append([(a-b)/b for a, b in zip(bins_ll, bins_tl)])
# C:\Users\marco\AppData\Local\Temp\ipykernel_9380\2407593847.py:6: RuntimeWarning: divide by zero encountered in scalar divide
#   pulls_tt.append([(a-b)/b for a, b in zip(bins_ll, bins_tt)])
# C:\Users\marco\AppData\Local\Temp\ipykernel_9380\2407593847.py:7: RuntimeWarning: divide by zero encountered in scalar divide
#   pulls_tx.append([(a-b)/b for a, b in zip(bins_ll, bins_tt+bins_tl)])
# C:\Users\marco\AppData\Local\Temp\ipykernel_9380\2407593847.py:5: RuntimeWarning: invalid value encountered in scalar divide
#   pulls_tl.append([(a-b)/b for a, b in zip(bins_ll, bins_tl)])
# C:\Users\marco\AppData\Local\Temp\ipykernel_9380\2407593847.py:6: RuntimeWarning: invalid value encountered in scalar divide
#   pulls_tt.append([(a-b)/b for a, b in zip(bins_ll, bins_tt)])
# ...

# %%
fig, ax = plt.subplots(ncols=4, nrows=8, figsize=(20,20))

for i in range(8):
    for j in range(4):
        ax[i,j].scatter(edgess_tl[i*4+j], pulls_tl[i*4+j], s=5)
        ax[i,j].scatter(edgess_tt[i*4+j], pulls_tt[i*4+j], s=5)
        ax[i,j].set_title(features[i*4+j])
        ax[i,j].hlines(0., min(edgess_tl[i*4+j]), max(edgess_tl[i*4+j]), color='k', linestyle='dashed', alpha=0.75)
        ax[i,j].set_ylim(-5, 5)
        #if log_mask[i*8+j]: ax[i,j].set_xscale('log')
fig.legend([hist_tl[0], hist_tt[0]], ['TT', 'TL'], loc="upper right", bbox_to_anchor=(0.9,1.))
plt.legend()
plt.tight_layout()
# Out:
# C:\Users\marco\AppData\Local\Temp\ipykernel_9380\613924413.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# for feature in features:
#     fig, ax = plt.subplots(ncols=1, nrows=2, figsize=(1.2*6.4, 1.4*4.8), gridspec_kw={'height_ratios': [3, 1]}, sharex='col')
#     bins_ll, edges_ll, hist_ll = ax[0].hist([x for x in df_ll[feature].to_numpy() if x != 0.], bins=50, density=True, histtype='step')
#     bins_tl, edges_tl, hist_tl = ax[0].hist([x for x in df_tl[feature].to_numpy() if x != 0.], bins=50, density=True, histtype='step')
#     bins_tt, edges_tt, hist_tt = ax[0].hist([x for x in df_tt[feature].to_numpy() if x != 0.], bins=50, density=True, histtype='step')
#     ax[0].tick_params(labelbottom=True)
#     edges_tl = [0.5*(e1+e2) for e1, e2 in zip(edges_tl[:-1], edges_tl[1:])]
#     edges_tt = [0.5*(e1+e2) for e1, e2 in zip(edges_ll[:-1], edges_ll[1:])]
#     pulls_tl = [(a-b)/(b+1.e-34) for a, b in zip(bins_ll, bins_tl)]
#     pulls_tt = [(a-b)/(b+1.e-34) for a, b in zip(bins_ll, bins_tt)]
#     #pulls_tx = [(a-b)/(b+1.e-34) for a, b in zip(bins_ll, bins_tl+bins_tt)]
#     scatt_tt = ax[1].scatter(edges_tt, pulls_tt, s=5, color='green')
#     scatt_tl = ax[1].scatter(edges_tl, pulls_tl, s=5, color='orange')
#     #scatt_tx = ax[1].scatter(edges_tl, pulls_tx, s=5, color='red')
#     xmin, xmax = ax[1].get_xlim()
#     ax[1].hlines(0., xmin, xmax, color='k', alpha=0.5)
#     ax[1].set_xlim(xmin, xmax)
#     ax[1].set_ylim(-2.5, 2.5)
#     if max(np.concatenate((np.abs(pulls_tl), np.abs(pulls_tt)))) < 1.25:
#         if max(np.concatenate((np.abs(pulls_tl), np.abs(pulls_tt)))) < 0.75:
#             ax[1].set_ylim(-0.75, 0.75)
#         else:
#             ax[1].set_ylim(-1.25, 1.25)
#     if feature == 'r_pt': ax[0].set_ylim(0., 5.e-5)
#     fig.suptitle(f'{feature}\nscalednorm histograms')
#     fig.legend([hist_ll[0], hist_tl[0], hist_tt[0]], ['LL', 'TL', 'TT'], ncols=2, loc="upper right", bbox_to_anchor=(0.9,1.))
#     plt.savefig(f'scalednorm/{feature}.png')
#     plt.show()

# %%
import hist

hist_2 = hist.Hist(
    hist.axis.Regular(
        50, -5, 5, name="X", label="x [units]", underflow=False, overflow=False
    )
).fill(df_tt['etav1'].to_numpy())

hist_1 = hist.Hist(
    hist.axis.Regular(
        50, -5, 5, name="X", label="x [units]", underflow=False, overflow=False
    )
).fill(df_ll['etav1'].to_numpy())

fig = plt.figure(figsize=(10, 8))
main_ax_artists, sublot_ax_arists = hist_1.plot_ratio(
    hist_2,
    rp_ylabel=r"Ratio",
    rp_num_label="hist1",
    rp_denom_label="hist2",
    rp_uncert_draw_type="bar",  # line or bar
)

# %%
fig, ax = plt.subplots(ncols=2, nrows=1, figsize=(18, 6))
histll = ax[0].hist2d(df_ll['detajj'], df_ll['mjj'], bins=100, cmap='ocean')
ax[0].set_xlabel('detajj')
ax[0].set_ylabel('mjj')
histtx = ax[1].hist2d(np.concatenate([df_tl['detajj'], df_tt['detajj']]), np.concatenate([df_tl['mjj'], df_tt['mjj']]), bins=100, cmap='magma')
ax[1].set_xlabel('detajj')
ax[1].set_ylabel('mjj')
plt.show()

# %%
fig, ax = plt.subplots(ncols=2, nrows=1, figsize=(18, 6))
ax[0].pcolormesh(histll[1], histll[2], histll[0]/(histtx[0]+1.e-34), cmap='cividis')
ax[0].set_xlabel('detajj')
ax[0].set_ylabel('mjj')
ax[0].set_title('ratio LL/TX')
ax[1].pcolormesh(histll[1], histll[2], histll[0]-histtx[0], cmap='winter')
ax[1].set_xlabel('detajj')
ax[1].set_ylabel('mjj')
ax[1].set_title('difference LL-TX')
plt.show()

# %%
fig, ax = plt.subplots(ncols=2, nrows=1, figsize=(18, 6))
histll = ax[0].hist2d(df_ll['ptMET'], df_ll['ptv1'], bins=100, cmap='magma')
ax[0].set_xlabel('ptMET')
ax[0].set_ylabel('ptv1')
histtx = ax[1].hist2d(np.concatenate([df_tl['ptMET'], df_tt['ptMET']]), np.concatenate([df_tl['ptv1'], df_tt['ptv1']]), bins=100, cmap='magma')
ax[1].set_xlabel('ptMET')
ax[1].set_ylabel('ptv1')
plt.show()

# %%
ids_nvbsjet = [k for k, v in f_dict.items() if 'nvbsjet' in v]
ids_nvbsjet
# Out:
# [14, 15, 16, 17, 18, 19, 20, 21]

# %%
data = np.load('../processed_ntuples/vanilla/chunk_data.npy')
mask = np.ones(shape=np.shape(data))

# %%
for i in range(len(data)):
    nvbs_jets = data[i][ids_nvbsjet[0]:ids_nvbsjet[-1]+1]
    nvbs_jet1 = nvbs_jets[::2]
    nvbs_jet2 = nvbs_jets[1::2]
    flag1 = all(f == 0. for f in nvbs_jet1)
    flag2 = all(f == 0. for f in nvbs_jet2)
    for j in ids_nvbsjet:
        if j % 2 == 0:
            if flag1:
                mask[i][j] = 0.
        else:
            if flag2:
                mask[i][j] = 0.
mask = np.array(mask, dtype=bool)

# %%
#

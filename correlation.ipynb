# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# # LL

# %%
lep_data_ll = np.load('LL/lep_data_ll.npy')
vbsjet_data_ll = np.load('LL/vbsjet_data_ll.npy')
nvbsjet_data_ll = np.load('LL/nvbsjet_data_ll.npy')
jj_data_ll = np.load('LL/jj_data_ll.npy')
met_data_ll = np.load('LL/met_data_ll.npy')
nu_data_ll = np.load('LL/nu_data_ll.npy')

# %%
lep_dic_ll = {'lepPt1': lep_data_ll.T[0,0], 'lepPt2': lep_data_ll.T[0,1], 'lepEta1': lep_data_ll.T[1,0], 'lepEta2': lep_data_ll.T[1,1], 'lepPhi1': lep_data_ll.T[2,0], 'lepPhi2': lep_data_ll.T[2,1]}
vbsjet_dic_ll = {'vbsjetPt1': vbsjet_data_ll.T[0,0], 'vbsjetPt2': vbsjet_data_ll.T[0,1], 'vbsjetEta1': vbsjet_data_ll.T[1,0], 'vbsjetEta2': vbsjet_data_ll.T[1,1], 'vbsjetPhi1': vbsjet_data_ll.T[2,0], 'vbsjetPhi2': vbsjet_data_ll.T[2,1], 'vbsjetM1': vbsjet_data_ll.T[3,0], 'vbsjetM2': vbsjet_data_ll.T[3,1]}
nvbsjet_dic_ll = {'nvbsjetPt1': nvbsjet_data_ll.T[0,0], 'nvbsjetPt2': nvbsjet_data_ll.T[0,1], 'nvbsjetEta1': nvbsjet_data_ll.T[1,0], 'nvbsjetEta2': nvbsjet_data_ll.T[1,1], 'nvbsjetPhi1': nvbsjet_data_ll.T[2,0], 'nvbsjetPhi2': nvbsjet_data_ll.T[2,1], 'nvbsjetM1': nvbsjet_data_ll.T[3,0], 'nvbsjetM2': nvbsjet_data_ll.T[3,1]}
jj_dic_ll = {'mjj': jj_data_ll.T[0,0], 'detajj': jj_data_ll.T[1,0]}
met_dic_ll = {'ptMET': met_data_ll.T[0,0], 'phiMET': met_data_ll.T[1,0]}
nu_dic_ll = {'ptv1': nu_data_ll.T[0,0], 'ptv2': nu_data_ll.T[0,1], 'etav1': nu_data_ll.T[1,0], 'etav2': nu_data_ll.T[1,1], 'phiv1': nu_data_ll.T[2,0], 'phiv2': nu_data_ll.T[2,1]}
dic_ll = vbsjet_dic_ll | lep_dic_ll | nvbsjet_dic_ll | jj_dic_ll | met_dic_ll | nu_dic_ll
df_ll = pd.DataFrame(dic_ll)

# %%
correlation_matrix_ll = df_ll.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix_ll, cmap='coolwarm', annot=False, vmin=-1, vmax=1, center=0)
plt.title('Correlation Heatmap of SSWW CMrf LL Events')
plt.savefig('LL_corr.png')

# %% [markdown]
# # TL

# %%
lep_data_tl = np.load('TL/lep_data_tl.npy')
vbsjet_data_tl = np.load('TL/vbsjet_data_tl.npy')
nvbsjet_data_tl = np.load('TL/nvbsjet_data_tl.npy')
jj_data_tl = np.load('TL/jj_data_tl.npy')
met_data_tl = np.load('TL/met_data_tl.npy')
nu_data_tl = np.load('TL/nu_data_tl.npy')

# %%
lep_dic_tl = {'lepPt1': lep_data_tl.T[0,0], 'lepPt2': lep_data_tl.T[0,1], 'lepEta1': lep_data_tl.T[1,0], 'lepEta2': lep_data_tl.T[1,1], 'lepPhi1': lep_data_tl.T[2,0], 'lepPhi2': lep_data_tl.T[2,1]}
vbsjet_dic_tl = {'vbsjetPt1': vbsjet_data_tl.T[0,0], 'vbsjetPt2': vbsjet_data_tl.T[0,1], 'vbsjetEta1': vbsjet_data_tl.T[1,0], 'vbsjetEta2': vbsjet_data_tl.T[1,1], 'vbsjetPhi1': vbsjet_data_tl.T[2,0], 'vbsjetPhi2': vbsjet_data_tl.T[2,1], 'vbsjetM1': vbsjet_data_tl.T[3,0], 'vbsjetM2': vbsjet_data_tl.T[3,1]}
nvbsjet_dic_tl = {'nvbsjetPt1': nvbsjet_data_tl.T[0,0], 'nvbsjetPt2': nvbsjet_data_tl.T[0,1], 'nvbsjetEta1': nvbsjet_data_tl.T[1,0], 'nvbsjetEta2': nvbsjet_data_tl.T[1,1], 'nvbsjetPhi1': nvbsjet_data_tl.T[2,0], 'nvbsjetPhi2': nvbsjet_data_tl.T[2,1], 'nvbsjetM1': nvbsjet_data_tl.T[3,0], 'nvbsjetM2': nvbsjet_data_tl.T[3,1]}
jj_dic_tl = {'mjj': jj_data_tl.T[0,0], 'detajj': jj_data_tl.T[1,0]}
met_dic_tl = {'ptMET': met_data_tl.T[0,0], 'phiMET': met_data_tl.T[1,0]}
nu_dic_tl = {'ptv1': nu_data_tl.T[0,0], 'ptv2': nu_data_tl.T[0,1], 'etav1': nu_data_tl.T[1,0], 'etav2': nu_data_tl.T[1,1], 'phiv1': nu_data_tl.T[2,0], 'phiv2': nu_data_tl.T[2,1]}
dic_tl = vbsjet_dic_tl | lep_dic_tl | nvbsjet_dic_tl | jj_dic_tl | met_dic_tl | nu_dic_tl
df_tl = pd.DataFrame(dic_tl)

# %%
correlation_matrix_tl = df_tl.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix_tl, cmap='coolwarm', annot=False, vmin=-1, vmax=1, center=0)
plt.title('Correlation Heatmap of SSWW CMrf TL Events')
plt.savefig('TL_corr.png')

# %% [markdown]
# # TT

# %%
lep_data_tt = np.load('TT/lep_data_tt.npy')
vbsjet_data_tt = np.load('TT/vbsjet_data_tt.npy')
nvbsjet_data_tt = np.load('TT/nvbsjet_data_tt.npy')
jj_data_tt = np.load('TT/jj_data_tt.npy')
met_data_tt = np.load('TT/met_data_tt.npy')
nu_data_tt = np.load('TT/nu_data_tt.npy')

# %%
len(vbsjet_data_tt.T[0,1])
# Out:
# 200115

# %%
lep_dic_tt = {'lepPt1': lep_data_tt.T[0,0], 'lepPt2': lep_data_tt.T[0,1], 'lepEta1': lep_data_tt.T[1,0], 'lepEta2': lep_data_tt.T[1,1], 'lepPhi1': lep_data_tt.T[2,0], 'lepPhi2': lep_data_tt.T[2,1]}
vbsjet_dic_tt = {'vbsjetPt1': vbsjet_data_tt.T[0,0], 'vbsjetPt2': vbsjet_data_tt.T[0,1], 'vbsjetEta1': vbsjet_data_tt.T[1,0], 'vbsjetEta2': vbsjet_data_tt.T[1,1], 'vbsjetPhi1': vbsjet_data_tt.T[2,0], 'vbsjetPhi2': vbsjet_data_tt.T[2,1], 'vbsjetM1': vbsjet_data_tt.T[3,0], 'vbsjetM2': vbsjet_data_tt.T[3,1]}
nvbsjet_dic_tt = {'nvbsjetPt1': nvbsjet_data_tt.T[0,0], 'nvbsjetPt2': nvbsjet_data_tt.T[0,1], 'nvbsjetEta1': nvbsjet_data_tt.T[1,0], 'nvbsjetEta2': nvbsjet_data_tt.T[1,1], 'nvbsjetPhi1': nvbsjet_data_tt.T[2,0], 'nvbsjetPhi2': nvbsjet_data_tt.T[2,1], 'nvbsjetM1': nvbsjet_data_tt.T[3,0], 'nvbsjetM2': nvbsjet_data_tt.T[3,1]}
jj_dic_tt = {'mjj': jj_data_tt.T[0,0], 'detajj': jj_data_tt.T[1,0]}
met_dic_tt = {'ptMET': met_data_tt.T[0,0], 'phiMET': met_data_tt.T[1,0]}
nu_dic_tt = {'ptv1': nu_data_tt.T[0,0], 'ptv2': nu_data_tt.T[0,1], 'etav1': nu_data_tt.T[1,0], 'etav2': nu_data_tt.T[1,1], 'phiv1': nu_data_tt.T[2,0], 'phiv2': nu_data_tt.T[2,1]}
dic_tt = vbsjet_dic_tt | lep_dic_tt | nvbsjet_dic_tt | jj_dic_tt | met_dic_tt | nu_dic_tt
df_tt = pd.DataFrame(dic_tt)

# %%
correlation_matrix_tt = df_tt.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix_tt, cmap='coolwarm', annot=False, vmin=-1, vmax=1, center=0)
plt.title('Correlation Heatmap of SSWW CMrf TT Events')
plt.savefig('TT_corr.png')

# %% [markdown]
# # all

# %%
df_tx = pd.concat([df_tl, df_tt])
correlation_matrix_tx = df_tx.corr()

# %%
df_ll['flag'] = 1
df_tx['flag'] = 0

# %%
df_fin = pd.concat([df_ll, df_tx])
df_fin
# Out:
#         vbsjetPt1  vbsjetPt2  vbsjetEta1  vbsjetEta2  vbsjetPhi1  vbsjetPhi2  \
# 0       -1.089352   0.144452   -0.992550    0.709488    0.496869   -0.853214
# 1       -0.366744  -0.437908   -1.145556    1.090068   -0.204952    1.091455
# 2        0.199381  -0.480528    0.700589   -1.326450    0.219315   -0.875620
# 3       -0.237110   0.724305    1.390020   -0.641935    0.671989   -0.376879
# 4       -0.609954  -0.749876   -1.146362    1.192145   -0.305519    1.063735
# ...           ...        ...         ...         ...         ...         ...
# 200110   1.117974   0.754074   -0.699016    0.643707    0.205015   -1.072266
# 200111  -0.384767   0.343451   -1.450111    0.761413   -0.387359    0.441948
# 200112   0.696440   0.509959    1.390492   -0.740706    0.831612   -1.293931
# 200113   0.022414  -0.571811   -0.522218    0.795808    0.083280   -5.218395
# 200114   1.158891   0.570893   -1.024203    1.181095    0.078285   -0.880470
#
#         vbsjetM1  vbsjetM2    lepPt1    lepPt2  ...    detajj     ptMET  \
# 0      -1.866402 -0.179653 -0.384219 -0.919335  ... -0.116316 -2.391653
# 1      -0.362715 -0.399508  1.231413 -0.419090  ...  1.159162 -1.096615
# 2       0.900761 -0.216044  1.459104  0.569787  ...  0.822838  1.375973
# 3       0.367491 -0.364289  1.131144  0.305541  ...  0.565911  0.491146
# 4      -0.665702 -0.845060 -0.308250 -0.420657  ... -0.557157 -1.370103
# ...          ...       ...       ...       ...  ...       ...       ...
# 200110  1.144871  0.814051  0.395589  0.192478  ... -0.861162 -3.086285
# 200111  0.498785  0.139327  1.288937  0.292290  ...  0.999137 -0.087697
# 200112  1.025291  0.750063  0.076040 -1.096191  ...  0.833299  0.915515
# 200113 -0.195240 -1.168826  0.949786  0.404208  ... -0.846819  0.319272
# 200114  0.782470  0.786571  0.680645 -0.002059  ...  1.167664  0.025261
#
#           phiMET      ptv1      ptv2     etav1     etav2     phiv1     phiv2  \
# 0       0.457193  0.019231 -0.449989 -0.246716 -0.568074  0.710084  0.373748
# 1       0.176937 -0.577807 -1.688216  0.540579 -2.450763  0.146524 -1.548312
# 2       2.331146  1.929732 -1.862359 -0.012642  0.690841 -3.300144  0.946830
# 3      -0.092609  0.698429 -0.654007 -0.583226  0.583511  0.275725 -0.251561
# 4      -0.775427  1.474939  0.692973  0.378954 -0.940571 -0.266078  1.388287
# ...          ...       ...       ...       ...       ...       ...       ...
# 200110 -0.481481  0.368256 -0.220876 -0.747246 -0.363812 -0.338052  1.113830
# 200111  0.050408 -0.391689 -2.023244 -0.937002 -0.062710 -0.306715 -0.127376
# 200112 -0.362732  1.002345  0.613555 -0.766064  0.003707 -0.217439 -0.329796
# 200113 -1.302284  1.595697  0.439514  0.595165 -0.283832 -1.049192  0.446542
# 200114  2.354128  0.547147  0.455096 -0.343425  0.446182  0.969370 -1.299840
#
#         flag
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 200110     0
# 200111     0
# 200112     0
# 200113     0
# 200114     0
#
# [527375 rows x 33 columns]

# %%
correlation_matrix_all = df_fin.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix_all, cmap='coolwarm', annot=False, vmin=-1, vmax=1, center=0)
plt.title('Correlation Heatmap of SSWW CMrf Events (flag: 1/0-LL/TX)')
plt.savefig('all_corr.png')

# %% [markdown]
# # Signal minus Background

# %%
correlation_matrix_smb = correlation_matrix_ll - correlation_matrix_tx

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix_smb, cmap='coolwarm', annot=False, center=0)
plt.title('Correlation Heatmap of SSWW CMrf Signal (LL) minus Background (TX) Events')
plt.savefig('smb_corr.png')

# %%
#

# %%
fig, ax = plt.subplots(ncols=3, nrows=1, figsize=(30, 8))
sns.heatmap(correlation_matrix_ll, ax=ax[0], cmap='coolwarm', annot=False, vmin=-1, vmax=1, center=0)
ax[0].set_title('Correlation Heatmap of SSWW CMrf LL Events')
sns.heatmap(correlation_matrix_tl, ax=ax[1], cmap='coolwarm', annot=False, vmin=-1, vmax=1, center=0)
ax[1].set_title('Correlation Heatmap of SSWW CMrf TL Events')
sns.heatmap(correlation_matrix_tt, ax=ax[2], cmap='coolwarm', annot=False, vmin=-1, vmax=1, center=0)
ax[2].set_title('Correlation Heatmap of SSWW CMrf TT Events')
plt.savefig('LLTLTT_corr.png')

# %%
fig, ax = plt.subplots(ncols=2, nrows=1, figsize=(20,8))
sns.heatmap(correlation_matrix_all, ax=ax[0], cmap='coolwarm', annot=False, vmin=-1, vmax=1, center=0)
ax[0].set_title('Correlation Heatmap of SSWW CMrf Events (flag: 1/0-LL/TX)')
sns.heatmap(correlation_matrix_smb, ax=ax[1], cmap='coolwarm', annot=False, center=0)
ax[1].set_title('Correlation Heatmap of SSWW CMrf Signal (LL) minus Background (TX) Events')
plt.savefig('all_diff_corr.png')

# %%
#
